# %%
import numpy as np
import matplotlib.pyplot as plt
from tools.fileloader import load_xyz_rot

# %%
# visualize generated submaps
# %matplotlib qt
submap_path = '/media/vectr/vectr3/Dataset/overlap_transformer/submaps/euclidean/botanical_garden/anchor.npy'
poses_path = '/media/vectr/vectr3/Dataset/overlap_transformer/poses/botanical_garden/poses.txt'
poses_kf_path = '/media/vectr/vectr3/Dataset/overlap_transformer/keyframes/botanical_garden/poses/poses_kf.txt'

xyz, _ = load_xyz_rot(poses_path)
xyz_kf, _ = load_xyz_rot(poses_kf_path)
submaps = np.load(submap_path)

for i in range(xyz.shape[0]):
    xyz_curr = xyz[i, :]
    xyz_curr_kf = xyz[submaps[i, :], :]

    plt.clf()
    plt.scatter(xyz[:, 0], xyz[:, 1])
    plt.scatter(xyz_kf[:, 0], xyz_kf[:, 1], c='gold')
    plt.scatter(xyz_curr_kf[:, 0], xyz_curr_kf[:, 1], c='red')
    plt.scatter(xyz_curr[0], xyz_curr[1], c='violet')
    plt.show()
    plt.pause(0.01)
# Out:
# [0 0 0 0 0]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 16
#      13 xyz_curr = xyz[i, :]
#      14 xyz_curr_kf = xyz[submaps[i, :], :]
# ---> 16 plt.clf()
#      17 plt.scatter(xyz[:, 0], xyz[:, 1])
#      18 plt.scatter(xyz_kf[:, 0], xyz_kf[:, 1], c='gold')
#
# File ~/anaconda3/envs/lidar_learning/lib/python3.10/site-packages/matplotlib/pyplot.py:997, in clf()
#     995 def clf():
#     996     """Clear the current figure."""
# --> 997     gcf().clear()
#
# File ~/anaconda3/envs/lidar_learning/lib/python3.10/site-packages/matplotlib/figure.py:3148, in Figure.clear(self, keep_observers)
#    3146 def clear(self, keep_observers=False):
#    3147     # docstring inherited
# -> 3148     super().clear(keep_observers=keep_observers)
#    3149     # FigureBase.clear does not clear toolbars, as
#    3150     # only Figure can have toolbars
# ...
